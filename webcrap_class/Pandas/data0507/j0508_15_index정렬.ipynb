# %%
import pandas as pd
data = {
    '이름':['강나래','강태원','강호림','김수찬','김재욱','박동현','박혜정','승근열'],
    '학교':['구로고','구로고','구로고','구로고','구로고','단지고','단지고','단지고'],
    '키':[197,184,168,187,188,202,188,190],
    '국어':[90,40,80,40,15,80,55,100],
    '영어':[85,35,75,60,20,100,65,85],
    '수학':[100,50,70,70,10,95,45,90],
    '과학':[95,55,80,75,35,85,40,95],
    '사회':[85,25,75,80,10,80,35,95],
    'SW특기':['Python','Java','javascript','','','C','PYTHON','c#']
}

# %%
df=pd.DataFrame(data)
df.set_index('키',inplace=True)
df.sort_index(ascending=True,inplace=True)
df
# Out:
#       이름   학교   국어   영어   수학  과학  사회        SW특기
# 키
# 168  강호림  구로고   80   75   70  80  75  javascript
# 184  강태원  구로고   40   35   50  55  25        Java
# 187  김수찬  구로고   40   60   70  75  80
# 188  김재욱  구로고   15   20   10  35  10
# 188  박혜정  단지고   55   65   45  40  35      PYTHON
# 190  승근열  단지고  100   85   90  95  95          c#
# 197  강나래  구로고   90   85  100  95  85      Python
# 202  박동현  단지고   80  100   95  85  80           C

# %%
df.sort_index(ascending=False,inplace=True)
df
# Out:
#       이름   학교   국어   영어   수학  과학  사회        SW특기
# 키
# 202  박동현  단지고   80  100   95  85  80           C
# 197  강나래  구로고   90   85  100  95  85      Python
# 190  승근열  단지고  100   85   90  95  95          c#
# 188  김재욱  구로고   15   20   10  35  10
# 188  박혜정  단지고   55   65   45  40  35      PYTHON
# 187  김수찬  구로고   40   60   70  75  80
# 184  강태원  구로고   40   35   50  55  25        Java
# 168  강호림  구로고   80   75   70  80  75  javascript

# %%
df.to_csv('score.csv',encoding='utf-8-sig')
df.to_csv('score.csv',encoding='utf-8') #csv 콤마형태로
df.to_csv('score.txt',encoding='utf-8',sep='\t') #csv 스테이스바 형태로
df.to_excel('score.xlsx') #엑셀로 저장하기

# %%
df=pd.read_csv('score.txt',index_col='지원번호')
df
# df=pd.read_csv('score.csv',index_col='지원번호')
# df
# df=pd.read_excel('score.xlsx')
# df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 df=pd.read_csv('score.txt',index_col='지원번호')
#       2 df
#       3 # df=pd.read_csv('score.csv',index_col='지원번호')
#       4 # df
#       5 # df=pd.read_excel('score.xlsx')
#       6 # df
#
# ...

# %%
df=pd.read_excel('score.xlsx',skiprows=1,nrows=3)
df
# Out:
#    202  박동현  단지고   80  100   95  85  80.1       C
# 0  197  강나래  구로고   90   85  100  95    85  Python
# 1  190  승근열  단지고  100   85   90  95    95      c#
# 2  188  김재욱  구로고   15   20   10  35    10     NaN
