# %%
import pandas as pd
df=pd.read_excel('../data/score.xlsx',index_col='지원번호')
df
# Out:
#        이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    강나래  구로고  197   90    5  100  95  85      python
# 2번    강태원  구로고  184   40   35   50  55  25        Java
# 3번    강호림  구로고  168   80   75   70  80  75  Javascript
# 4번    김수찬  구로고  187   40   60   70  75  80         NaN
# 5번    김재욱  구로고  188   15   20   10  35  10         NaN
# 6번    박동현  구로고  202   80  100   95  85  80           C
# 7번    박혜정  단지고  188   55   65   45  40  35      PYTHON
# 8번    승근열  단지고  190  100   85   90  95  95          C#

# %%
df['이름']
# Out:
# 지원번호
# 1번    강나래
# 2번    강태원
# 3번    강호림
# 4번    김수찬
# 5번    김재욱
# 6번    박동현
# 7번    박혜정
# 8번    승근열
# Name: 이름, dtype: object

# %%
df.columns
# Out:
# Index(['이름', '학교', '키', '국어', '영어', '수학', '과학', '사회', 'SW특기'], dtype='object')

# %%
df[df.columns[1:3]]
# Out:
#        학교    키
# 지원번호
# 1번    구로고  197
# 2번    구로고  184
# 3번    구로고  168
# 4번    구로고  187
# 5번    구로고  188
# 6번    구로고  202
# 7번    단지고  188
# 8번    단지고  190

# %%
df[['학교','이름']]
# Out:
#        학교   이름
# 지원번호
# 1번    구로고  강나래
# 2번    구로고  강태원
# 3번    구로고  강호림
# 4번    구로고  김수찬
# 5번    구로고  김재욱
# 6번    구로고  박동현
# 7번    단지고  박혜정
# 8번    단지고  승근열

# %% [markdown]
# # 인덱스기준으로 역순정렬

# %%
df.sort_index(ascending=False)# 인덱스기준으로 역순정렬
# Out:
#        이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 8번    승근열  단지고  190  100   85   90  95  95          C#
# 7번    박혜정  단지고  188   55   65   45  40  35      PYTHON
# 6번    박동현  구로고  202   80  100   95  85  80           C
# 5번    김재욱  구로고  188   15   20   10  35  10         NaN
# 4번    김수찬  구로고  187   40   60   70  75  80         NaN
# 3번    강호림  구로고  168   80   75   70  80  75  Javascript
# 2번    강태원  구로고  184   40   35   50  55  25        Java
# 1번    강나래  구로고  197   90    5  100  95  85      python

# %%
df['키'].sort_values() #키 작은순부터큰순으로 정렬
# Out:
# 지원번호
# 3번    168
# 2번    184
# 4번    187
# 5번    188
# 7번    188
# 8번    190
# 1번    197
# 6번    202
# Name: 키, dtype: int64

# %%
name1=['aaa','bbb','ccc','ddd','eee',]
births1=[968,155,77,578,973]
custom1=[1,5,25,13,23232]

# list(zip(name,births,custom))
bSet =list(zip(name,births,custom))

df=pd.DataFrame(data=bSet,columns=['name','births','custom'])
df

# # 기존방법
# data={
#     "name":name1,"births":births1,"custom":custom1
# }

# df=pd.DataFrame(data)
# df
# Out:
#   name  births  custom
# 0  aaa     968       1
# 1  bbb     155       5
# 2  ccc      77      25
# 3  ddd     578      13
# 4  eee     973   23232
