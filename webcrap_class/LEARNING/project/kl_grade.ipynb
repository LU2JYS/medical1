# %% [markdown]
# ### 라이브러리 임포트

# %%
import os
import numpy as np
import pandas as pd
import torch
import torchvision
import cv2
import random
import seaborn as sns
import matplotlib.pyplot as plt
from PIL import Image
from torch.utils.data import DataLoader

# %%
torch.__version__
# Out:
# '2.3.1'

# %%
torchvision.__version__
# Out:
# '0.18.1'

# %% [markdown]
# ### 경로 설정
#  - 현재 폴더 경로를 찾기
#  - 슬관절 데이터가 전부 담긴 폴더 찾기
#  - 하위 폴더 경로를 각각 변수에 저장

# %%
os.getcwd()
# Out:
# 'c:\\Users\\Harvey\\Desktop\\Codes\\Python\\practice'

# %%
base_dir = os.getcwd() + '\\data\\datasets\\osteoarthritis'

train_dir = os.path.join(base_dir, 'train')
val_dir = os.path.join(base_dir, 'val')
test_dir = os.path.join(base_dir, 'test')

# %%
test_dir
# Out:
# 'c:\\Users\\Harvey\\Desktop\\Codes\\Python\\practice\\data\\datasets\\osteoarthritis\\test'

# %%
os.listdir(base_dir)[1:]

os.listdir(os.path.join(train_dir,'0'))
# Out:
# ['9001695L.png',
#  '9001695L_br.png',
#  '9001695L_clahe.png',
#  '9001695L_no.png',
#  '9001897L.png',
#  '9001897L_br.png',
#  '9001897L_clahe.png',
#  '9001897L_no.png',
#  '9003126L.png',
#  '9003126L_br.png',
#  '9003126L_clahe.png',
#  '9003126L_no.png',
#  '9003126R.png',
#  '9003126R_br.png',
#  '9003126R_clahe.png',
#  '9003126R_no.png',
#  '9003430L.png',
#  '9003430L_br.png',
#  '9003430L_clahe.png',
#  '9003430L_no.png',
#  '9003658L.png',
#  '9003658L_br.png',
#  '9003658L_clahe.png',
#  '9003658L_no.png',
#  '9003658R.png',
#  '9003658R_br.png',
#  '9003658R_clahe.png',
#  '9003658R_no.png',
#  '9004315L.png',
#  '9004315L_br.png',
#  '9004315L_clahe.png',
#  '9004315L_no.png',
#  '9004315R.png',
#  '9004315R_br.png',
#  '9004315R_clahe.png',
#  '9004315R_no.png',
#  '9004669L.png',
#  '9004669L_br.png',
#  '9004669L_clahe.png',
#  '9004669L_no.png',
#  '9004669R.png',
#  '9004669R_br.png',
#  '9004669R_clahe.png',
#  '9004669R_no.png',
#  '9005075L.png',
#  '9005075L_br.png',
#  '9005075L_clahe.png',
#  '9005075L_no.png',
#  '9005075R.png',
#  '9005075R_br.png',
#  '9005075R_clahe.png',
#  '9005075R_no.png',
#  '9005321L.png',
#  '9005321L_br.png',
#  '9005321L_clahe.png',
#  '9005321L_no.png',
#  '9005321R.png',
#  '9005321R_br.png',
#  '9005321R_clahe.png',
#  '9005321R_no.png',
#  '9005656L.png',
#  '9005656L_br.png',
#  '9005656L_clahe.png',
#  '9005656L_no.png',
#  '9005656R.png',
#  '9005656R_br.png',
#  '9005656R_clahe.png',
#  '9005656R_no.png',
#  '9007904L.png',
#  '9007904L_br.png',
#  '9007904L_clahe.png',
#  '9007904L_no.png',
#  '9007904R.png',
#  '9007904R_br.png',
#  '9007904R_clahe.png',
#  '9007904R_no.png',
#  '9008820L.png',
#  '9008820L_br.png',
#  '9008820L_clahe.png',
#  '9008820L_no.png',
#  '9008820R.png',
#  '9008820R_br.png',
#  '9008820R_clahe.png',
#  '9008820R_no.png',
#  '9009623L.png',
#  '9009623L_br.png',
#  '9009623L_clahe.png',
#  '9009623L_no.png',
#  '9009623R.png',
#  '9009623R_br.png',
#  '9009623R_clahe.png',
#  '9009623R_no.png',
#  '9010370L.png',
#  '9010370L_br.png',
#  '9010370L_clahe.png',
#  '9010370L_no.png',
#  '9010952L.png',
#  '9010952L_br.png',
#  '9010952L_clahe.png',
#  '9010952L_no.png',
#  '9010952R.png',
#  '9010952R_br.png',
#  '9010952R_clahe.png',
#  '9010952R_no.png',
#  '9011115L.png',
#  '9011115L_br.png',
#  '9011115L_clahe.png',
#  '9011115L_no.png',
#  '9011115R.png',
#  '9011115R_br.png',
#  '9011115R_clahe.png',
#  '9011115R_no.png',
#  '9011641L.png',
#  '9011641L_br.png',
#  '9011641L_clahe.png',
#  '9011641L_no.png',
#  '9011641R.png',
#  '9011641R_br.png',
#  '9011641R_clahe.png',
#  '9011641R_no.png',
#  '9011949L.png',
#  '9011949L_br.png',
#  '9011949L_clahe.png',
#  '9011949L_no.png',
#  '9011949R.png',
#  '9011949R_br.png',
#  '9011949R_clahe.png',
#  '9011949R_no.png',
#  '9013634R.png',
#  '9013634R_br.png',
#  '9013634R_clahe.png',
#  '9013634R_no.png',
#  '9014883R.png',
#  '9014883R_br.png',
#  '9014883R_clahe.png',
#  '9014883R_no.png',
#  '9015363L.png',
#  '9015363L_br.png',
#  '9015363L_clahe.png',
#  '9015363L_no.png',
#  '9015798L.png',
#  '9015798L_br.png',
#  '9015798L_clahe.png',
#  '9015798L_no.png',
#  '9016121L.png',
#  '9016121L_br.png',
#  '9016121L_clahe.png',
#  '9016121L_no.png',
#  '9016121R.png',
#  '9016121R_br.png',
#  '9016121R_clahe.png',
#  '9016121R_no.png',
#  '9016179L.png',
#  '9016179L_br.png',
#  '9016179L_clahe.png',
#  '9016179L_no.png',
#  '9016179R.png',
#  '9016179R_br.png',
#  '9016179R_clahe.png',
#  '9016179R_no.png',
#  '9016886L.png',
#  '9016886L_br.png',
#  '9016886L_clahe.png',
#  '9016886L_no.png',
#  '9016886R.png',
#  '9016886R_br.png',
#  '9016886R_clahe.png',
#  '9016886R_no.png',
#  '9017909L.png',
#  '9017909L_br.png',
#  '9017909L_clahe.png',
#  '9017909L_no.png',
#  '9017909R.png',
#  '9017909R_br.png',
#  '9017909R_clahe.png',
#  '9017909R_no.png',
#  '9018489L.png',
#  '9018489L_br.png',
#  '9018489L_clahe.png',
#  '9018489L_no.png',
#  '9018489R.png',
#  '9018489R_br.png',
#  '9018489R_clahe.png',
#  '9018489R_no.png',
#  '9019287L.png',
#  '9019287L_br.png',
#  '9019287L_clahe.png',
#  '9019287L_no.png',
#  '9019406L.png',
#  '9019406L_br.png',
#  '9019406L_clahe.png',
#  '9019406L_no.png',
#  '9019406R.png',
#  '9019406R_br.png',
#  '9019406R_clahe.png',
#  '9019406R_no.png',
#  '9020856L.png',
#  '9020856L_br.png',
#  '9020856L_clahe.png',
#  '9020856L_no.png',
#  '9020856R.png',
#  '9020856R_br.png',
#  '9020856R_clahe.png',
#  '9020856R_no.png',
#  '9020999L.png',
#  '9020999L_br.png',
#  '9020999L_clahe.png',
#  '9020999L_no.png',
#  '9020999R.png',
#  '9020999R_br.png',
#  '9020999R_clahe.png',
#  '9020999R_no.png',
#  '9021195L.png',
#  '9021195L_br.png',
#  '9021195L_clahe.png',
#  '9021195L_no.png',
#  '9021195R.png',
#  '9021195R_br.png',
#  '9021195R_clahe.png',
#  '9021195R_no.png',
#  '9022197L.png',
#  '9022197L_br.png',
#  '9022197L_clahe.png',
#  '9022197L_no.png',
#  '9022289L.png',
#  '9022289L_br.png',
#  '9022289L_clahe.png',
#  '9022289L_no.png',
#  '9022289R.png',
#  '9022289R_br.png',
#  '9022289R_clahe.png',
#  '9022289R_no.png',
#  '9022703L.png',
#  '9022703L_br.png',
#  '9022703L_clahe.png',
#  '9022703L_no.png',
#  '9022703R.png',
#  '9022703R_br.png',
#  '9022703R_clahe.png',
#  '9022703R_no.png',
#  '9022789L.png',
#  '9022789L_br.png',
#  '9022789L_clahe.png',
#  '9022789L_no.png',
#  '9023193L.png',
#  '9023193L_br.png',
#  '9023193L_clahe.png',
#  '9023193L_no.png',
#  '9023407L.png',
#  '9023407L_br.png',
#  '9023407L_clahe.png',
#  '9023407L_no.png',
#  '9023407R.png',
#  '9023407R_br.png',
#  '9023407R_clahe.png',
#  '9023407R_no.png',
#  '9025191L.png',
#  '9025191L_br.png',
#  '9025191L_clahe.png',
#  '9025191L_no.png',
#  '9025933L.png',
#  '9025933L_br.png',
#  '9025933L_clahe.png',
#  '9025933L_no.png',
#  '9025933R.png',
#  '9025933R_br.png',
#  '9025933R_clahe.png',
#  '9025933R_no.png',
#  '9027281L.png',
#  '9027281L_br.png',
#  '9027281L_clahe.png',
#  '9027281L_no.png',
#  '9027281R.png',
#  '9027281R_br.png',
#  '9027281R_clahe.png',
#  '9027281R_no.png',
#  '9028904L.png',
#  '9028904L_br.png',
#  '9028904L_clahe.png',
#  '9028904L_no.png',
#  '9028904R.png',
#  '9028904R_br.png',
#  '9028904R_clahe.png',
#  '9028904R_no.png',
#  '9029791L.png',
#  '9029791L_br.png',
#  '9029791L_clahe.png',
#  '9029791L_no.png',
#  '9030296L.png',
#  '9030296L_br.png',
#  '9030296L_clahe.png',
#  '9030296L_no.png',
#  '9030296R.png',
#  '9030296R_br.png',
#  '9030296R_clahe.png',
#  '9030296R_no.png',
#  '9033937L.png',
#  '9033937L_br.png',
#  '9033937L_clahe.png',
#  '9033937L_no.png',
#  '9033937R.png',
#  '9033937R_br.png',
#  '9033937R_clahe.png',
#  '9033937R_no.png',
#  '9034644L.png',
#  '9034644L_br.png',
#  '9034644L_clahe.png',
#  '9034644L_no.png',
#  '9034677L.png',
#  '9034677L_br.png',
#  '9034677L_clahe.png',
#  '9034677L_no.png',
#  '9034677R.png',
#  '9034677R_br.png',
#  '9034677R_clahe.png',
#  '9034677R_no.png',
#  '9034963L.png',
#  '9034963L_br.png',
#  '9034963L_clahe.png',
#  '9034963L_no.png',
#  '9034963R.png',
#  '9034963R_br.png',
#  '9034963R_clahe.png',
#  '9034963R_no.png',
#  '9035647R.png',
#  '9035647R_br.png',
#  '9035647R_clahe.png',
#  '9035647R_no.png',
#  '9036770L.png',
#  '9036770L_br.png',
#  '9036770L_clahe.png',
#  '9036770L_no.png',
#  '9036770R.png',
#  '9036770R_br.png',
#  '9036770R_clahe.png',
#  '9036770R_no.png',
#  '9036771R.png',
#  '9036771R_br.png',
#  '9036771R_clahe.png',
#  '9036771R_no.png',
#  '9036948L.png',
#  '9036948L_br.png',
#  '9036948L_clahe.png',
#  '9036948L_no.png',
#  '9036948R.png',
#  '9036948R_br.png',
#  '9036948R_clahe.png',
#  '9036948R_no.png',
#  '9037223R.png',
#  '9037223R_br.png',
#  '9037223R_clahe.png',
#  '9037223R_no.png',
#  '9037697L.png',
#  '9037697L_br.png',
#  '9037697L_clahe.png',
#  '9037697L_no.png',
#  '9037697R.png',
#  '9037697R_br.png',
#  '9037697R_clahe.png',
#  '9037697R_no.png',
#  '9037952L.png',
#  '9037952L_br.png',
#  '9037952L_clahe.png',
#  '9037952L_no.png',
#  '9037952R.png',
#  '9037952R_br.png',
#  '9037952R_clahe.png',
#  '9037952R_no.png',
#  '9038683L.png',
#  '9038683L_br.png',
#  '9038683L_clahe.png',
#  '9038683L_no.png',
#  '9038683R.png',
#  '9038683R_br.png',
#  '9038683R_clahe.png',
#  '9038683R_no.png',
#  '9038962R.png',
#  '9038962R_br.png',
#  '9038962R_clahe.png',
#  '9038962R_no.png',
#  '9039972L.png',
#  '9039972L_br.png',
#  '9039972L_clahe.png',
#  '9039972L_no.png',
#  '9039972R.png',
#  '9039972R_br.png',
#  '9039972R_clahe.png',
#  '9039972R_no.png',
#  '9040390L.png',
#  '9040390L_br.png',
#  '9040390L_clahe.png',
#  '9040390L_no.png',
#  '9040456L.png',
#  '9040456L_br.png',
#  '9040456L_clahe.png',
#  '9040456L_no.png',
#  '9040892L.png',
#  '9040892L_br.png',
#  '9040892L_clahe.png',
#  '9040892L_no.png',
#  '9040892R.png',
#  '9040892R_br.png',
#  '9040892R_clahe.png',
#  '9040892R_no.png',
#  '9040944L.png',
#  '9040944L_br.png',
#  '9040944L_clahe.png',
#  '9040944L_no.png',
#  '9041946L.png',
#  '9041946L_br.png',
#  '9041946L_clahe.png',
#  '9041946L_no.png',
#  '9041946R.png',
#  '9041946R_br.png',
#  '9041946R_clahe.png',
#  '9041946R_no.png',
#  '9042459L.png',
#  '9042459L_br.png',
#  '9042459L_clahe.png',
#  '9042459L_no.png',
#  '9042459R.png',
#  '9042459R_br.png',
#  '9042459R_clahe.png',
#  '9042459R_no.png',
#  '9043507L.png',
#  '9043507L_br.png',
#  '9043507L_clahe.png',
#  '9043507L_no.png',
#  '9043637R.png',
#  '9043637R_br.png',
#  '9043637R_clahe.png',
#  '9043637R_no.png',
#  '9044788R.png',
#  '9044788R_br.png',
#  '9044788R_clahe.png',
#  '9044788R_no.png',
#  '9048979R.png',
#  '9048979R_br.png',
#  '9048979R_clahe.png',
#  '9048979R_no.png',
#  '9049007R.png',
#  '9049007R_br.png',
#  '9049007R_clahe.png',
#  '9049007R_no.png',
#  '9049895R.png',
#  '9049895R_br.png',
#  '9049895R_clahe.png',
#  '9049895R_no.png',
#  '9050299R.png',
#  '9050299R_br.png',
#  '9050299R_clahe.png',
#  '9050299R_no.png',
#  '9051960L.png',
#  '9051960L_br.png',
#  '9051960L_clahe.png',
#  '9051960L_no.png',
#  '9051960R.png',
#  '9051960R_br.png',
#  '9051960R_clahe.png',
#  '9051960R_no.png',
#  '9052207L.png',
#  '9052207L_br.png',
#  '9052207L_clahe.png',
#  '9052207L_no.png',
#  '9052207R.png',
#  '9052207R_br.png',
#  '9052207R_clahe.png',
#  '9052207R_no.png',
#  '9052335L.png',
#  '9052335L_br.png',
#  '9052335L_clahe.png',
#  '9052335L_no.png',
#  '9052708L.png',
#  '9052708L_br.png',
#  '9052708L_clahe.png',
#  '9052708L_no.png',
#  '9053679L.png',
#  '9053679L_br.png',
#  '9053679L_clahe.png',
#  '9053679L_no.png',
#  '9053679R.png',
#  '9053679R_br.png',
#  '9053679R_clahe.png',
#  '9053679R_no.png',
#  '9053872L.png',
#  '9053872L_br.png',
#  '9053872L_clahe.png',
#  '9053872L_no.png',
#  '9053872R.png',
#  '9053872R_br.png',
#  '9053872R_clahe.png',
#  '9053872R_no.png',
#  '9054370R.png',
#  '9054370R_br.png',
#  '9054370R_clahe.png',
#  '9054370R_no.png',
#  '9055429R.png',
#  '9055429R_br.png',
#  '9055429R_clahe.png',
#  '9055429R_no.png',
#  '9057000L.png',
#  '9057000L_br.png',
#  '9057000L_clahe.png',
#  '9057000L_no.png',
#  '9057000R.png',
#  '9057000R_br.png',
#  '9057000R_clahe.png',
#  '9057000R_no.png',
#  '9058469L.png',
#  '9058469L_br.png',
#  '9058469L_clahe.png',
#  '9058469L_no.png',
#  '9059339R.png',
#  '9059339R_br.png',
#  '9059339R_clahe.png',
#  '9059339R_no.png',
#  '9061162L.png',
#  '9061162L_br.png',
#  '9061162L_clahe.png',
#  '9061162L_no.png',
#  '9061162R.png',
#  '9061162R_br.png',
#  '9061162R_clahe.png',
#  '9061162R_no.png',
#  '9061805L.png',
#  '9061805L_br.png',
#  '9061805L_clahe.png',
#  '9061805L_no.png',
#  '9061805R.png',
#  '9061805R_br.png',
#  '9061805R_clahe.png',
#  '9061805R_no.png',
#  '9062483R.png',
#  '9062483R_br.png',
#  '9062483R_clahe.png',
#  '9062483R_no.png',
#  '9062645L.png',
#  '9062645L_br.png',
#  '9062645L_clahe.png',
#  '9062645L_no.png',
#  '9062688L.png',
#  '9062688L_br.png',
#  '9062688L_clahe.png',
#  '9062688L_no.png',
#  '9062962L.png',
#  '9062962L_br.png',
#  '9062962L_clahe.png',
#  '9062962L_no.png',
#  '9062962R.png',
#  '9062962R_br.png',
#  '9062962R_clahe.png',
#  '9062962R_no.png',
#  '9063823L.png',
#  '9063823L_br.png',
#  '9063823L_clahe.png',
#  '9063823L_no.png',
#  '9063823R.png',
#  '9063823R_br.png',
#  '9063823R_clahe.png',
#  '9063823R_no.png',
#  '9064631R.png',
#  '9064631R_br.png',
#  '9064631R_clahe.png',
#  '9064631R_no.png',
#  '9065433R.png',
#  '9065433R_br.png',
#  '9065433R_clahe.png',
#  '9065433R_no.png',
#  '9065926R.png',
#  '9065926R_br.png',
#  '9065926R_clahe.png',
#  '9065926R_no.png',
#  '9066677L.png',
#  '9066677L_br.png',
#  '9066677L_clahe.png',
#  '9066677L_no.png',
#  '9066677R.png',
#  '9066677R_br.png',
#  '9066677R_clahe.png',
#  '9066677R_no.png',
#  '9066820L.png',
#  '9066820L_br.png',
#  '9066820L_clahe.png',
#  '9066820L_no.png',
#  '9066820R.png',
#  '9066820R_br.png',
#  '9066820R_clahe.png',
#  '9066820R_no.png',
#  '9068894L.png',
#  '9068894L_br.png',
#  '9068894L_clahe.png',
#  '9068894L_no.png',
#  '9069761L.png',
#  '9069761L_br.png',
#  '9069761L_clahe.png',
#  '9069761L_no.png',
#  '9069761R.png',
#  '9069761R_br.png',
#  '9069761R_clahe.png',
#  '9069761R_no.png',
#  '9069786L.png',
#  '9069786L_br.png',
#  '9069786L_clahe.png',
#  '9069786L_no.png',
#  '9069786R.png',
#  '9069786R_br.png',
#  '9069786R_clahe.png',
#  '9069786R_no.png',
#  '9070442R.png',
#  '9070442R_br.png',
#  '9070442R_clahe.png',
#  '9070442R_no.png',
#  '9070787L.png',
#  '9070787L_br.png',
#  '9070787L_clahe.png',
#  '9070787L_no.png',
#  '9070787R.png',
#  '9070787R_br.png',
#  '9070787R_clahe.png',
#  '9070787R_no.png',
#  '9070923R.png',
#  '9070923R_br.png',
#  '9070923R_clahe.png',
#  '9070923R_no.png',
#  '9072461L.png',
#  '9072461L_br.png',
#  '9072461L_clahe.png',
#  '9072461L_no.png',
#  '9072461R.png',
#  '9072461R_br.png',
#  '9072461R_clahe.png',
#  '9072461R_no.png',
#  '9072758L.png',
#  '9072758L_br.png',
#  '9072758L_clahe.png',
#  '9072758L_no.png',
#  '9072758R.png',
#  '9072758R_br.png',
#  '9072758R_clahe.png',
#  '9072758R_no.png',
#  '9073948L.png',
#  '9073948L_br.png',
#  '9073948L_clahe.png',
#  '9073948L_no.png',
#  '9073948R.png',
#  '9073948R_br.png',
#  '9073948R_clahe.png',
#  '9073948R_no.png',
#  '9075418R.png',
#  '9075418R_br.png',
#  '9075418R_clahe.png',
#  '9075418R_no.png',
#  '9075880L.png',
#  '9075880L_br.png',
#  '9075880L_clahe.png',
#  '9075880L_no.png',
#  '9075880R.png',
#  '9075880R_br.png',
#  '9075880R_clahe.png',
#  '9075880R_no.png',
#  '9077395L.png',
#  '9077395L_br.png',
#  '9077395L_clahe.png',
#  '9077395L_no.png',
#  '9079404L.png',
#  '9079404L_br.png',
#  '9079404L_clahe.png',
#  '9079404L_no.png',
#  '9079404R.png',
#  '9079404R_br.png',
#  '9079404R_clahe.png',
#  '9079404R_no.png',
#  '9080864L.png',
#  '9080864L_br.png',
#  '9080864L_clahe.png',
#  '9080864L_no.png',
#  '9080864R.png',
#  '9080864R_br.png',
#  '9080864R_clahe.png',
#  '9080864R_no.png',
#  '9081362L.png',
#  '9081362L_br.png',
#  '9081362L_clahe.png',
#  '9081362L_no.png',
#  '9082640L.png',
#  '9082640L_br.png',
#  '9082640L_clahe.png',
#  '9082640L_no.png',
#  '9082640R.png',
#  '9082640R_br.png',
#  '9082640R_clahe.png',
#  '9082640R_no.png',
#  '9082901R.png',
#  '9082901R_br.png',
#  '9082901R_clahe.png',
#  '9082901R_no.png',
#  '9083500L.png',
#  '9083500L_br.png',
#  '9083500L_clahe.png',
#  '9083500L_no.png',
#  '9084244L.png',
#  '9084244L_br.png',
#  '9084244L_clahe.png',
#  '9084244L_no.png',
#  '9084391L.png',
#  '9084391L_br.png',
#  '9084391L_clahe.png',
#  '9084391L_no.png',
#  '9084391R.png',
#  '9084391R_br.png',
#  '9084391R_clahe.png',
#  '9084391R_no.png',
#  '9085162L.png',
#  '9085162L_br.png',
#  '9085162L_clahe.png',
#  '9085162L_no.png',
#  '9085162R.png',
#  '9085162R_br.png',
#  '9085162R_clahe.png',
#  '9085162R_no.png',
#  '9085393L.png',
#  '9085393L_br.png',
#  '9085393L_clahe.png',
#  '9085393L_no.png',
#  '9085393R.png',
#  '9085393R_br.png',
#  '9085393R_clahe.png',
#  '9085393R_no.png',
#  '9086407L.png',
#  '9086407L_br.png',
#  '9086407L_clahe.png',
#  '9086407L_no.png',
#  '9086407R.png',
#  '9086407R_br.png',
#  '9086407R_clahe.png',
#  '9086407R_no.png',
#  '9086868R.png',
#  '9086868R_br.png',
#  '9086868R_clahe.png',
#  '9086868R_no.png',
#  '9088617L.png',
#  '9088617L_br.png',
#  '9088617L_clahe.png',
#  '9088617L_no.png',
#  '9088617R.png',
#  '9088617R_br.png',
#  '9088617R_clahe.png',
#  '9088617R_no.png',
#  '9089627L.png',
#  '9089627L_br.png',
#  '9089627L_clahe.png',
#  '9089627L_no.png',
#  '9089627R.png',
#  '9089627R_br.png',
#  '9089627R_clahe.png',
#  '9089627R_no.png',
#  '9089866L.png',
#  '9089866L_br.png',
#  '9089866L_clahe.png',
#  '9089866L_no.png',
#  '9089866R.png',
#  '9089866R_br.png',
#  '9089866R_clahe.png',
#  '9089866R_no.png',
#  '9090290L.png',
#  '9090290L_br.png',
#  '9090290L_clahe.png',
#  '9090290L_no.png',
#  '9090290R.png',
#  '9090290R_br.png',
#  '9090290R_clahe.png',
#  '9090290R_no.png',
#  '9090833L.png',
#  '9090833L_br.png',
#  '9090833L_clahe.png',
#  '9090833L_no.png',
#  '9090833R.png',
#  '9090833R_br.png',
#  '9090833R_clahe.png',
#  '9090833R_no.png',
#  '9091337R.png',
#  '9091337R_br.png',
#  '9091337R_clahe.png',
#  '9091337R_no.png',
#  '9091787L.png',
#  '9091787L_br.png',
#  '9091787L_clahe.png',
#  '9091787L_no.png',
#  '9091787R.png',
#  '9091787R_br.png',
#  '9091787R_clahe.png',
#  '9091787R_no.png',
#  '9094841R.png',
#  '9094841R_br.png',
#  '9094841R_clahe.png',
#  '9094841R_no.png',
#  '9095839L.png',
#  '9095839L_br.png',
#  '9095839L_clahe.png',
#  '9095839L_no.png',
#  '9095839R.png',
#  '9095839R_br.png',
#  '9095839R_clahe.png',
#  '9095839R_no.png',
#  '9096402R.png',
#  '9096402R_br.png',
#  '9096402R_clahe.png',
#  '9096402R_no.png',
#  '9096851L.png',
#  '9096851L_br.png',
#  '9096851L_clahe.png',
#  '9096851L_no.png',
#  '9096856L.png',
#  '9096856L_br.png',
#  '9096856L_clahe.png',
#  '9096856L_no.png',
#  '9096856R.png',
#  '9096856R_br.png',
#  '9096856R_clahe.png',
#  '9096856R_no.png',
#  '9096881L.png',
#  '9096881L_br.png',
#  '9096881L_clahe.png',
#  '9096881L_no.png',
#  '9096881R.png',
#  '9096881R_br.png',
#  '9096881R_clahe.png',
#  '9096881R_no.png',
#  '9098882L.png',
#  '9098882L_br.png',
#  '9098882L_clahe.png',
#  '9098882L_no.png',
#  '9098924R.png',
#  '9098924R_br.png',
#  '9098924R_clahe.png',
#  '9098924R_no.png',
#  '9099440L.png',
#  '9099440L_br.png',
#  '9099440L_clahe.png',
#  '9099440L_no.png',
#  '9099440R.png',
#  '9099440R_br.png',
#  '9099440R_clahe.png',
#  '9099440R_no.png',
#  '9099961L.png',
#  '9099961L_br.png',
#  '9099961L_clahe.png',
#  '9099961L_no.png',
#  '9100442L.png',
#  '9100442L_br.png',
#  '9100442L_clahe.png',
#  '9100442L_no.png',
#  '9100442R.png',
#  '9100442R_br.png',
#  '9100442R_clahe.png',
#  '9100442R_no.png',
#  '9102258L.png',
#  '9102258L_br.png',
#  '9102258L_clahe.png',
#  '9102258L_no.png',
#  '9102258R.png',
#  '9102258R_br.png',
#  '9102258R_clahe.png',
#  '9102258R_no.png',
#  '9102958L.png',
#  '9102958L_br.png',
#  '9102958L_clahe.png',
#  '9102958L_no.png',
#  '9102958R.png',
#  '9102958R_br.png',
#  '9102958R_clahe.png',
#  '9102958R_no.png',
#  '9104043R.png',
#  '9104043R_br.png',
#  '9104043R_clahe.png',
#  '9104043R_no.png',
#  '9105279L.png',
#  '9105279L_br.png',
#  '9105279L_clahe.png',
#  '9105279L_no.png',
#  '9105279R.png',
#  '9105279R_br.png',
#  '9105279R_clahe.png',
#  '9105279R_no.png',
#  '9106510L.png',
#  '9106510L_br.png',
#  '9106510L_clahe.png',
#  '9106510L_no.png',
#  '9106510R.png',
#  '9106510R_br.png',
#  '9106510R_clahe.png',
#  '9106510R_no.png',
#  '9106808L.png',
#  '9106808L_br.png',
#  '9106808L_clahe.png',
#  '9106808L_no.png',
#  '9106808R.png',
#  '9106808R_br.png',
#  '9106808R_clahe.png',
#  '9106808R_no.png',
#  '9107524L.png',
#  '9107524L_br.png',
#  '9107524L_clahe.png',
#  '9107524L_no.png',
#  '9107524R.png',
#  '9107524R_br.png',
#  '9107524R_clahe.png',
#  '9107524R_no.png',
#  '9108461L.png',
#  '9108461L_br.png',
#  '9108461L_clahe.png',
#  '9108461L_no.png',
#  '9108461R.png',
#  '9108461R_br.png',
#  '9108461R_clahe.png',
#  '9108461R_no.png',
#  '9108688R.png',
#  '9108688R_br.png',
#  '9108688R_clahe.png',
#  '9108688R_no.png',
#  '9108945L.png',
#  '9108945L_br.png',
#  '9108945L_clahe.png',
#  '9108945L_no.png',
#  '9109448L.png',
#  '9109448L_br.png',
#  '9109448L_clahe.png',
#  '9109448L_no.png',
#  '9109950L.png',
#  '9109950L_br.png',
#  '9109950L_clahe.png',
#  '9109950L_no.png',
#  '9109950R.png',
#  '9109950R_br.png',
#  '9109950R_clahe.png',
#  '9109950R_no.png',
#  '9110292L.png',
#  '9110292L_br.png',
#  '9110292L_clahe.png',
#  '9110292L_no.png',
#  '9110292R.png',
#  '9110292R_br.png',
#  '9110292R_clahe.png',
#  '9110292R_no.png',
#  '9111399L.png',
#  '9111399L_br.png',
#  '9111399L_clahe.png',
#  '9111399L_no.png',
#  '9111399R.png',
#  '9111399R_br.png',
#  '9111399R_clahe.png',
#  '9111399R_no.png',
#  '9112976L.png',
#  '9112976L_br.png',
#  '9112976L_clahe.png',
#  '9112976L_no.png',
#  '9112976R.png',
#  '9112976R_br.png',
#  '9112976R_clahe.png',
#  '9112976R_no.png',
#  '9113192L.png',
#  '9113192L_br.png',
#  '9113192L_clahe.png',
#  '9113192L_no.png',
#  '9113192R.png',
#  '9113192R_br.png',
#  '9113192R_clahe.png',
#  '9113192R_no.png',
#  '9113414L.png',
#  '9113414L_br.png',
#  '9113414L_clahe.png',
#  '9113414L_no.png',
#  '9113501L.png',
#  '9113501L_br.png',
#  '9113501L_clahe.png',
#  '9113501L_no.png',
#  '9113501R.png',
#  '9113501R_br.png',
#  '9113501R_clahe.png',
#  '9113501R_no.png',
#  '9114285L.png',
#  '9114285L_br.png',
#  '9114285L_clahe.png',
#  '9114285L_no.png',
#  '9114285R.png',
#  '9114285R_br.png',
#  '9114285R_clahe.png',
#  '9114285R_no.png',
#  '9114544L.png',
#  '9114544L_br.png',
#  '9114544L_clahe.png',
#  '9114544L_no.png',
#  '9114544R.png',
#  '9114544R_br.png',
#  '9114544R_clahe.png',
#  '9114544R_no.png',
#  '9115742L.png',
#  '9115742L_br.png',
#  '9115742L_clahe.png',
#  '9115742L_no.png',
#  ...]

# %% [markdown]
# ### 폴더 경로를 활용해서 이미지 불러오기, 라벨링 하기
#  - 폴더 구조를 보면 훈련세트, 검증세트, 테스트 세트가 분리되어 있고 하위 폴더에 KL등급(0~4)별로 폴더가 있고 그 안에 이미지가 있음
#  - 따라서, 이미지-KL등급을 한 묶음으로 데이터 구조를 만들예정 ex) [[이미지데이터, kl등급]] -> [[(224*224)의 이미지 데이터 행렬, 0],...]
#  - 라벨링은 폴더명 자체를 활용하여 등급을 매길 예정

# %%
def load_dataset(base_dir):
    dataset_all =  {} # 전체 데이터를 담을 딕셔너리
    
    # 훈련, 검증, 테스트 폴더 별로 데이터를 하나씩 불러올 예정
    folder_list = os.listdir(base_dir)[1:] # auto-test 폴더는 제외
    
    for folder in folder_list:
        dataset = [] # 훈련, 검증, 테스트 별 정보를 담을 리스트
        split_folder = os.path.join(base_dir, folder) # 현재 작업할 폴더
        # print('cur1 : ',split_folder)
        labels = os.listdir(split_folder) # 각 등급별로 폴더 확인 ['0', '1', '2', '3', '4']
        for label in labels:
            current_folder = f'{split_folder}\\{label}'
            # print('cur2 :',current_folder)
            file_list = os.listdir(current_folder) # 현재 폴더에 있는 파일 불러오기
            for file in file_list:
                file_info = {} # 이미지 경로와, 라벨링 값을 담을 딕셔너리
                file_info['file_path'] = os.path.join(current_folder, file)
                file_info['class'] = int(label)
                dataset.append(file_info)
        dataset_all[folder] = dataset
        
    return dataset_all

# %%
dataset = load_dataset(base_dir)

# %% [markdown]
# ### 데이터 정보 확인

# %%
print(len(dataset['train']), len(dataset['val']), len(dataset['test']))
print(dataset['train'][0])
# Out:
# 23112 3304 1656
# {'file_path': 'c:\\Users\\Harvey\\Desktop\\Codes\\Python\\practice\\data\\datasets\\osteoarthritis\\train\\0\\9001695L.png', 'class': 0}

# %%
df = pd.DataFrame(dataset['train'])
df['class'].value_counts()
# Out:
# class
# 0    9144
# 2    6064
# 1    4184
# 3    3028
# 4     692
# Name: count, dtype: int64

# %%
sns.countplot(x='class', data=df)
# Out:
# <Axes: xlabel='class', ylabel='count'>

# %% [markdown]
# ### 데이터 가져오기

# %% [markdown]
# ### 랜덤으로 데이터 가져오기
#  - pandas 데이터 프레임에서 각 등급별로 5개씩만 추출해보고 인덱스를 저장한 후 출력

# %%
# 등급별로 랜덤으로 5개씩 뽑아오기

SAMPLE_SIZE = 5
labels = df['class'].unique()
rand_idx = []
for label in labels:
    idx_list = df.groupby('class').get_group(label).sample(SAMPLE_SIZE).index.astype(int)
    rand_idx.append(idx_list)
    
rand_idx # 0등급부터 차례대로 5개씩 인덱스가 저장되어있음
# Out:
# [Index([6697, 3553, 3579, 3683, 6562], dtype='int32'),
#  Index([12912, 11690, 13103, 9812, 9810], dtype='int32'),
#  Index([17818, 16391, 17224, 15506, 18848], dtype='int32'),
#  Index([21724, 19990, 19537, 21054, 20559], dtype='int32'),
#  Index([23106, 22458, 22449, 22970, 22721], dtype='int32')]

# %%
fig, axs = plt.subplots(5, 5, figsize=(20, 15)) # 5 x 5 형태로 출력
plt.tight_layout()

for ax, indice in zip(axs, rand_idx): # 훈련 데이터중 등급별로 5개씩 불러와보기 
    for i, idx in enumerate(indice): # 1줄에 5개씩 출력
        img = cv2.imread(dataset['train'][idx]['file_path'], cv2.IMREAD_GRAYSCALE) # 이미지 경로를 이용해 이미지를 흑백으로 불러오고 img변수에 저장
        ax[i].imshow(img, cmap='gray')
        ax[i].set_title(f"class : {dataset['train'][idx]['class']}") # 
        ax[i].axis(False)

# %% [markdown]
# ### 데이터 이미지 전처리 함수 만들어보기
#  - x-ray 데이터는 히스토그램 평활화 기법을 이용해서 대비를 증가 시킴
#  - HEQ(Histogram EQualization)
#  - AHE(Adaptive Histogram Equalization)
#  - CLAHE(Contrast Limited Adaptive Histogram Equalization)

# %%
def check_image_preprocessing(image_path):
    
    # 원본 이미지
    origin_img = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    # origin_img = cv2.resize(origin_img, (96, 96))
    rows, cols = origin_img.shape[:2]
    hist = cv2.calcHist([origin_img], [0], None, [256], [0, 256])
    
    # HEQ 적용
    processed_img = cv2.equalizeHist(origin_img)
    hist2 = cv2.calcHist([processed_img], [0], None, [256], [0, 256])
    
    # CLAHE 적용
    clahe = cv2.createCLAHE(clipLimit=2.5, tileGridSize=(8, 8))
    clahe_img = clahe.apply(origin_img)
    hist3 = cv2.calcHist([clahe_img], [0], None, [256], [0, 256])
    
    # 가우시안 블러 적용
    blur_img = cv2.GaussianBlur(origin_img, (3, 3), sigmaX=1, sigmaY=1)
    hist4 = cv2.calcHist([blur_img], [0], None, [256], [0, 256])
    
    # 이미지랑 밝기 분포 확인
    plt.figure(figsize=(20, 10))
    plt.subplot(2, 4, 1)
    plt.imshow(origin_img, cmap='gray')
    plt.title('origin_image')
    plt.subplot(2, 4, 2)
    plt.title('equailized_image')
    plt.imshow(processed_img, cmap='gray')
    plt.subplot(2, 4, 3)
    plt.title('CLAHE_image')
    plt.imshow(clahe_img, cmap='gray')
    plt.subplot(2, 4, 4)
    plt.title('Blur_image')
    plt.imshow(blur_img, cmap='gray')
    plt.subplot(2, 4, 5)
    plt.title('origin_hist')
    plt.plot(hist)
    plt.subplot(2, 4, 6)
    plt.plot(hist2)
    plt.title('equilzed_hist')
    plt.subplot(2, 4, 7)
    plt.plot(hist3)
    plt.title('CLAHE_hist')
    plt.subplot(2, 4, 8)
    plt.plot(hist4)
    plt.title('Blur_hist')

# %%
check_image_preprocessing(dataset['train'][0]['file_path'])

# %% [markdown]
# ### 데이터 증강하기
#  - 기존 데이터셋은 좌우대칭(flip)만 있음(L, 또는 R로 끝남)
#  - 노이즈 추가, 랜덤으로 블러링 한 경우를 추가함

# %%
def make_noise(img, std=10):
    height, width = img.shape
    noise = np.zeros_like(img, dtype='float')
    for i in range(height):
        for j in range(width):
            ran_noise = np.random.normal()
            set_noise = std * ran_noise
            noise[i][j] = img[i][j] + set_noise
 
    return noise

# %%
os.listdir(base_dir)
# Out:
# ['auto_test', 'test', 'train', 'val']

# %%
# 증강함수는 실행하지마세요
# def data_augmentation(base_dir):
    
#     folder_list = ['train', 'val'] # 훈련, 검증 데이터만 증강
    
#     for folder in folder_list:
#         split_folder = os.path.join(base_dir, folder) # 현재 작업할 폴더
#         labels = os.listdir(split_folder) # 각 등급별로 폴더 확인 ['0', '1', '2', '3', '4']
#         for label in labels: 
#             current_folder = f'{split_folder}\\{label}'
#             file_list = os.listdir(current_folder) # 현재 폴더에 있는 파일 불러오기
#             # print(current_folder)
#             for file in file_list:
#                 file_path = os.path.join(current_folder, file)
#                 origin_img = cv2.imread(file_path, cv2.IMREAD_GRAYSCALE)
#                 randblur = random.uniform(0, 1)
#                 blur_img = cv2.GaussianBlur(origin_img, (5, 5), sigmaX=randblur, sigmaY=randblur)
#                 # noise image
#                 noise_img = make_noise(origin_img)
#                 clahe = cv2.createCLAHE(clipLimit=2.5, tileGridSize=(8, 8))
#                 clahe_img = clahe.apply(origin_img)
#                 cv2.imwrite(current_folder + '\\' + file.split('.')[0]+'_br.png', blur_img)
#                 cv2.imwrite(current_folder + '\\' + file.split('.')[0]+'_no.png', noise_img)
#                 cv2.imwrite(current_folder + '\\' + file.split('.')[0]+'_clahe.png', clahe_img)

# %%
# data_augmentation(base_dir)

# %% [markdown]
# ### 증강된 데이터 확인

# %%
data = load_dataset(base_dir)
print(len(data['train']), len(data['val']), len(data['test']))
print(data['train'][0:3])
# Out:
# 23112 3304 1656
# [{'file_path': 'c:\\Users\\Harvey\\Desktop\\Codes\\Python\\practice\\data\\datasets\\osteoarthritis\\train\\0\\9001695L.png', 'class': 0}, {'file_path': 'c:\\Users\\Harvey\\Desktop\\Codes\\Python\\practice\\data\\datasets\\osteoarthritis\\train\\0\\9001695L_br.png', 'class': 0}, {'file_path': 'c:\\Users\\Harvey\\Desktop\\Codes\\Python\\practice\\data\\datasets\\osteoarthritis\\train\\0\\9001695L_clahe.png', 'class': 0}]

# %%
br_img = cv2.imread(os.path.join(train_dir, '0\\9001695L_br.png'), cv2.IMREAD_GRAYSCALE)
no_img = cv2.imread(os.path.join(train_dir, '0\\9001695L_no.png'), cv2.IMREAD_GRAYSCALE)
clahe_img = cv2.imread(os.path.join(train_dir, '0\\9001695L_clahe.png'), cv2.IMREAD_GRAYSCALE)
plt.figure(figsize=(10, 5))
plt.subplot(1, 3, 1)
plt.imshow(br_img, cmap='gray')
plt.axis(False)
plt.title('blurred_image')
plt.subplot(1, 3, 2)
plt.title('noised_image')
plt.imshow(no_img, cmap='gray')
plt.axis(False)
plt.subplot(1, 3, 3)
plt.title('CLAHE_image')
plt.imshow(clahe_img, cmap='gray')
plt.axis(False)
plt.show()

# %% [markdown]
# ### 훈련 데이터셋 만들기

# %%
transform = torchvision.transforms.Compose([torchvision.transforms.Resize((128, 128)), # 224 * 224 * 3채널 -> 128 * 128
                                            # torchvision.transforms.Grayscale(1), # 1채널의 흑백으로 변경                                            
                                            torchvision.transforms.ToTensor(), # tensor로 자료형 변환
                                            torchvision.transforms.Normalize([0.6058561,0.6058561,0.6058561], [0.15344825, 0.15344825, 0.15344825])
                                            ])
# 각 데이터 별로 적용
train_data = torchvision.datasets.ImageFolder(root=train_dir, transform=transform)
val_data = torchvision.datasets.ImageFolder(root=val_dir, transform=transform)
test_data = torchvision.datasets.ImageFolder(root=test_dir, transform=transform)

# %%
# meanRGB = [np.mean(x.numpy(), axis=(1,2)) for x,_ in train_data]
# stdRGB = [np.std(x.numpy(), axis=(1,2)) for x,_ in train_data]

# meanR = np.mean([m[0] for m in meanRGB])
# meanG = np.mean([m[1] for m in meanRGB])
# meanB = np.mean([m[2] for m in meanRGB])

# stdR = np.mean([s[0] for s in stdRGB])
# stdG = np.mean([s[1] for s in stdRGB])
# stdB = np.mean([s[2] for s in stdRGB])
# print("평균",meanR, meanG, meanB)
# print("표준편차",stdR, stdG, stdB)

# %%
train = DataLoader(train_data, batch_size=36, shuffle=True, num_workers=4)
test = DataLoader(test_data, batch_size=36, shuffle=True, num_workers=4)

# %% [markdown]
# ### 훈련모델 생성

# %%
"""
총 훈련 데이터 개수 23112개
배치 사이즈 : 36
에폭 : 642 (23112 / 36)

input : 3 x 128 x 128 흑백 컬러사진

------------- 1차 신경망 ---------------

* 1번째 컨벌루션 연산
input : 3 x 128 x 128 -> output : 32 x 128 x 128

* 활성화 함수(렐루) 적용

* 1번째 맥스 풀링 연산
input : 32 x 128 x 128 -> output : 32 x 64 x 64

* 활성화 함수(렐루) 적용

* 2번째 컨벌루션 연산
input : 32 x 64 x 64 -> output : 64 x 64 x 64

* 2번째 맥스 풀링 연산
input : 64 x 64 x 64 -> output : 64 x 32 x 32

------------ Flatten 진행 (view함수로 1차원 데이터로 늘어놓음)-------------

input : 64 x 32 x 32 -> output : 131072(64x32x32)

------------- 2차 신경망 ---------------
* 1번째 선형 연산
input : 131072(64x32x32) -> output : 30

* 활성화 함수(렐루) 적용

* 2번째 선형 연산
input : 30 -> output : 5

* 소프트맥스 함수 적용
input : 5 -> output : 5(각 등급별로 확률이 표시됨)
[0등급일 확률, 1등급일 확률, 2등급일 확률, 3등급일 확률, 4등급일 확률]
"""

class KL_Classfier(torch.nn.Module):
    def __init__(self):
        super(KL_Classfier, self).__init__()
        
        self.layer1 = torch.nn.Sequential(torch.nn.Conv2d(3, 64, 3, stride=1, padding='same'),
                                         torch.nn.ReLU(),
                                         torch.nn.MaxPool2d(2, 2, padding=0)
                                         )
        self.layer2 = torch.nn.Sequential(torch.nn.Conv2d(64, 128, 3, stride=1, padding='same'),
                                         torch.nn.ReLU(),
                                         torch.nn.MaxPool2d(2, 2, padding=0),
                                         torch.nn.Dropout(0.2)
                                         )
        # self.layer3 = torch.nn.Sequential(torch.nn.Conv2d(128, 256, 3, stride=1, padding='same'),
        #                                  torch.nn.LeakyReLU(0.1),
        #                                  torch.nn.MaxPool2d(2, 2, padding=0),
        #                                  torch.nn.Dropout(0.2)
        #                                  )
        
        self.fc_layer = torch.nn.Sequential(torch.nn.Linear(128 * 32 * 32, 30),
                                            torch.nn.LeakyReLU(0.1),
                                            torch.nn.Linear(30, 5),
                                            torch.nn.Softmax(dim=1)
                                            )
    def forward(self, x):
        out = self.layer1(x) # 1차 신경망
        out = self.layer2(out) # 2차 신경망
        # out = self.layer3(out) # 3차 신경망
        out = out.view(36, -1) # flatten, batch_size : 36
        out = self.fc_layer(out) # 4차 신경망
        
        return out

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda', index=0)

# %%
kl_cnn = KL_Classfier().to(device)

# %%
criterion = torch.nn.CrossEntropyLoss()
# optimizer = torch.optim.SGD(kl_cnn.parameters(), lr=0.001, momentum=0.8)
optimizer = torch.optim.Adam(kl_cnn.parameters(), lr=0.001, weight_decay=0.2)

# %%
kl_cnn.train()
for epoch in range(20):
    for index, (data, target) in enumerate(train):
        data, target = data.to(device), target.to(device)
        optimizer.zero_grad()
        output = kl_cnn(data)
        loss = criterion(output, target)
        loss.backward()
        optimizer.step()
        
    print("epoch : {}, loss : {}".format(epoch, loss.item()))
# Out:
# epoch : 0, loss : 1.6408627033233643
# epoch : 1, loss : 1.3956185579299927
# epoch : 2, loss : 1.5207079648971558
# epoch : 3, loss : 1.4480798244476318
# epoch : 4, loss : 1.4405128955841064
# epoch : 5, loss : 1.4962077140808105
# epoch : 6, loss : 1.5340583324432373
# epoch : 7, loss : 1.5130802392959595
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[89], line 4
#       2 for epoch in range(20):
#       3     for index, (data, target) in enumerate(train):
# ----> 4         data, target = data.to(device), target.to(device)
#       5         optimizer.zero_grad()
#       6         output = kl_cnn(data)
#
# KeyboardInterrupt:
