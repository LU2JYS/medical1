# %%
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
import pandas as pd
matplotlib.rcParams['axes.unicode_minus'] = False  # 마이너스 표시 해결
matplotlib.rcParams['font.family'] = 'Malgun Gothic' # windows 사용자
matplotlib.rcParams['font.size'] = '10' # 글자크기

# %%
import pandas as pd
df = pd.read_excel('../data/score1.xlsx',index_col='지원번호')
df.head(3)
# Out:
#        이름   학교  학년    키  국어  영어   수학  과학  사회        SW특기
# 지원번호
# 1번    강나래  구로고   3  197  90  85  100  95  85      Python
# 2번    강태원  구로고   3  184  40  35   50  55  25        Java
# 3번    강호림  구로고   2  168  80  75   70  80  75  javascript

# %%
plt.bar(df['이름'],df['국어'])
# Out:
# <BarContainer object of 8 artists>

# %% [markdown]
# ## subplots(2,2) 그래프 여러개그리기

# %%
fig,axs=plt.subplots(2,2,figsize=(10,10))


#0,0에 그래프 작성
# 범례
axs[0,0].bar(df['이름'],df['국어'],label='국어점수')
axs[0,0].legend()
axs[0,0].set_title('국어 그래프')
axs[0,0].set(xlabel='이름',ylabel='국어점수')
axs[0,0].set_facecolor('#efefef')
axs[0,0].grid(linestyle='--',alpha=0.5)

axs[2,2].bar(df['이름'],df['수학'],label='국어점수')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[31], line 13
#      10 axs[0,0].set_facecolor('#efefef')
#      11 axs[0,0].grid(linestyle='--',alpha=0.5)
# ---> 13 axs[2,2].bar(df['이름'],df['국어'],label='국어점수')
#      14 axs[0,0].legend()
#      15 axs[0,0].set_title('국어 그래프')
#
# IndexError: index 2 is out of bounds for axis 0 with size 2
