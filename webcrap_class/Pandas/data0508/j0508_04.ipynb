# %%
import pandas as pd
#index_col=0 첫번째 컬럼을 index로 지정
#skiprows: 상단부분 제외
#nrows: 가져오기
df=pd.read_excel('20122022_출생.xlsx',skiprows=2,usecols='B:M')
df.index.name='제목'
df
# Out:
# c:\Python312\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[10], line 5
#       1 import pandas as pd
#       2 #index_col=0 첫번째 컬럼을 index로 지정
#       3 #skiprows: 상단부분 제외
#       4 #nrows: 가져오기
# ----> 5 df=pd.read_excel('20122022_출생.xlsx',skiprows=2,usecols='B:M', index_col=0)
#       6 df.index.name='제목'
#       7 df
#
# ...

# %%
df.index.values
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df.index.values
#
# NameError: name 'df' is not defined

# %%
# index 이름변경
