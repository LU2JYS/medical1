# %%
import pandas as pd
#index_col=0 첫번째 컬럼을 index로 지정
#skiprows: 상단부분 제외
#nrows: 가져오기
df=pd.read_excel('20122022_출생.xlsx',skiprows=2, usecols='B:M',index_col=0)
df.index.name='제목'
df
# Out:
# c:\Python312\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#                                                        2012     2013     2014  \
# 제목
# 출생아수(명)                                             484,550  436,455  435,435
# 조출생률(인구1천명당 명)                                          9.6      8.6      8.6
# 합계출산율(가임여성1명당 명)                                      1.297    1.187    1.205
# 사망자수(명)                                             267,221  266,257  267,692
# 조사망률(인구1천명당 명)                                          5.3      5.3      5.3
# 전체(년)                                                 80.90    81.40    81.80
# 남자(년)                                                 77.60    78.10    78.60
# 여자(년)                                                 84.20    84.60    85.00
# ...

# %%
df.index.values
# Out:
# array(['출생', nan, nan, '사망', nan, '기대수명', nan, nan, '출처:', '주석:'],
#       dtype=object)

# %%
# index 이름변경

# %%
df.rename(index={'합계출산율(가임여성1명당\xa0명)':'합계출산율(가임여성1명당 명)'},inplace=True)
df
# Out:
#                                                        2012     2013     2014  \
# 제목
# 출생아수(명)                                             484,550  436,455  435,435
# 조출생률(인구1천명당 명)                                          9.6      8.6      8.6
# 합계출산율(가임여성1명당 명)                                      1.297    1.187    1.205
# 사망자수(명)                                             267,221  266,257  267,692
# 조사망률(인구1천명당 명)                                          5.3      5.3      5.3
# 전체(년)                                                 80.90    81.40    81.80
# 남자(년)                                                 77.60    78.10    78.60
# 여자(년)                                                 84.20    84.60    85.00
# 101003호, 인구동향조사                                         NaN      NaN      NaN
# * 기대수명(Life expectancy at birth): 0세 출생자가 향후 생존...      NaN      NaN      NaN
#
#                                                        2015     2016     2017  \
# 제목
# ...

# %%
df.loc['출생아수(명)']
# Out:
# 2012    484,550
# 2013    436,455
# 2014    435,435
# 2015    438,420
# 2016    406,243
# 2017    357,771
# 2018    326,822
# 2019    302,676
# 2020    272,337
# 2021    260,562
# 2022    249,186
# Name: 출생아수(명), dtype: object

# %%
df=df.T #rows,columns 축 변경
df
# df['2012']
# Out:
# 제목    출생아수(명) 조출생률(인구1천명당 명) 합계출산율(가임여성1명당 명)  사망자수(명) 조사망률(인구1천명당 명)  전체(년)  \
# 2012  484,550            9.6            1.297  267,221            5.3  80.90
# 2013  436,455            8.6            1.187  266,257            5.3  81.40
# 2014  435,435            8.6            1.205  267,692            5.3  81.80
# 2015  438,420            8.6            1.239  275,895            5.4  82.10
# 2016  406,243            7.9            1.172  280,827            5.5  82.40
# 2017  357,771            7.0            1.052  285,534            5.6  82.70
# 2018  326,822            6.4            0.977  298,820            5.8  82.70
# 2019  302,676            5.9            0.918  295,110            5.7  83.30
# 2020  272,337            5.3            0.837  304,948            5.9  83.50
# 2021  260,562            5.1            0.808  317,680            6.2  83.60
# 2022  249,186            4.9            0.778  372,939            7.3  82.70
#
# 제목    남자(년)  여자(년) 101003호, 인구동향조사  \
# ...
